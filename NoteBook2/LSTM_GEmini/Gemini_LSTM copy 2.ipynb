# %%
# ==============================================================================
# SECCIÓN 0: CONFIGURACIÓN INICIAL E IMPORTACIÓN DE LIBRERÍAS
# ==============================================================================
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from sklearn.preprocessing import MinMaxScaler
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import optuna

# AJUSTE: Suprimir advertencias para una salida más limpia
import warnings
warnings.filterwarnings('ignore')

# --- Configuración de Gráficos y PyTorch ---
plt.style.use('seaborn-v0_8-whitegrid')
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Usando dispositivo: {device}")
os.makedirs('output', exist_ok=True)

# ==============================================================================
# SECCIÓN 1: ANÁLISIS EXPLORATORIO DE DATOS (EDA)
# ==============================================================================
print("\n--- Iniciando Sección 1: Carga y Análisis Exploratorio de Datos ---")

# --- 1.1 Carga de Datos ---
DATA_PATH = '../../Datos/'
try:
    df_train = pd.read_parquet(f'{DATA_PATH}df_train.parquet')
    df_train_raw =  df_train[df_train['anio'] < 2021] #pd.read_csv(f'{DATA_PATH}df_train.csv')
    df_test_raw =  df_train[df_train['anio'] == 2021] #pd.read_csv(f'{DATA_PATH}df_test.csv')
    sample_submission = pd.read_csv(f'{DATA_PATH}sample_submission.csv')
    print("Archivos cargados exitosamente.")
    # Identificar el nombre real de la columna de casos
    TARGET = [col for col in df_train_raw.columns if 'dengue' in col.lower()][0]
    print(f"Variable objetivo identificada como: '{TARGET}'")
except FileNotFoundError:
    print(f"Error: No se encontraron los archivos en la ruta '{DATA_PATH}'.")
    exit()
except IndexError:
    print("Error: No se pudo identificar la columna de casos en 'df_train.csv'. Asegúrate de que exista.")
    exit()

# --- 1.2 Preprocesamiento de Datos (Fechas, Categorías, Nulos) ---
print("\nIniciando preprocesamiento de datos...")
train_len = len(df_train_raw)
full_df_raw = pd.concat([df_train_raw, df_test_raw], axis=0, ignore_index=True)

# Manejo de la variable categórica 'estrato'
if 'estrato' in full_df_raw.columns:
    print("Codificando la variable categórica 'estrato'...")
    full_df_processed = pd.get_dummies(full_df_raw, columns=['estrato'], drop_first=True)
else:
    full_df_processed = full_df_raw.copy()

# Crear el índice de tiempo usando 'anio' y 'semana'
full_df_processed['date'] = pd.to_datetime(
    full_df_processed['anio'].astype(str) + full_df_processed['semana'].astype(str) + '-1',
    format='%Y%W-%w'
)

# Ordenar los datos cronológicamente
full_df_processed.sort_values(by='date', inplace=True)
full_df_processed.set_index('date', inplace=True)

# Rellenar valores NaN usando interpolación lineal
full_df_processed.interpolate(method='linear', inplace=True, limit_direction='both')
full_df_processed.fillna(method='bfill', inplace=True)
full_df_processed.fillna(method='ffill', inplace=True)

# Separar de nuevo en entrenamiento y prueba
df_train = full_df_processed.iloc[:train_len].copy()
df_test = full_df_processed.iloc[train_len:].copy()
print("Preprocesamiento completado.")

# --- 1.3 Análisis de la Serie de Tiempo del Target ---
plt.figure(figsize=(18, 6))
df_train[TARGET].plot(label=f'Casos de Dengue ({TARGET})')
plt.title('Casos de Dengue a lo largo del tiempo (Entrenamiento)')
plt.xlabel('Fecha')
plt.ylabel('Número de Casos')
plt.legend()
plt.savefig('output/eda_timeseries_plot.png')
plt.show()

# Descomposición estacional
decomposition = seasonal_decompose(df_train[TARGET], model='additive', period=52)
fig = decomposition.plot()
fig.set_size_inches(14, 10)
plt.savefig('output/eda_decomposition.png')
plt.show()

# --- 1.4 Análisis de Correlación ---
plt.figure(figsize=(16, 14))
corr_cols = [col for col in df_train.columns if col not in ['anio', 'semana']]
correlation_matrix = df_train[corr_cols].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Matriz de Correlación de Variables')
plt.savefig('output/eda_correlation_matrix.png')
plt.show()

# ==============================================================================
# SECCIÓN 2: MODELO LSTM CON PYTORCH Y OPTIMIZACIÓN CON OPTUNA
# ==============================================================================
print("\n--- Iniciando Sección 2: Modelo LSTM y Optimización de Hiperparámetros ---")

# --- 2.1 Preparación de Datos para LSTM ---
# Seleccionar features excluyendo columnas de tiempo y el target
features = [col for col in df_train.columns if col not in [TARGET, 'anio', 'semana']]
if 'ESTRATO' in features:
    features.remove('ESTRATO')

# AJUSTE: Excluir la columna 'lluvia_min' de las características si existe
if 'lluvia_min' in features:
    print("Excluyendo la columna 'lluvia_min' de las características.")
    features.remove('lluvia_min')

features = ['lluvia_mean', 'temperatura_mean']

print(f"\nCaracterísticas finales para el modelo ({len(features)}): {features}")
num_features = len(features)

# Escalar las características
scaler_features = MinMaxScaler()
scaler_target = MinMaxScaler()

df_train_scaled = df_train.copy()
df_test_scaled = df_test.copy()

df_train_scaled[features] = scaler_features.fit_transform(df_train[features])
df_train_scaled[TARGET] = scaler_target.fit_transform(df_train[[TARGET]])
df_test_scaled[features] = scaler_features.transform(df_test[features])

def create_sequences(input_data, target_data, sequence_length):
    X, y = [], []
    for i in range(len(input_data) - sequence_length):
        X.append(input_data[i:(i + sequence_length)])
        y.append(target_data[i + sequence_length])
    return np.array(X), np.array(y)

# --- 2.2 Definición del Modelo LSTM ---
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size, dropout_rate):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers,
                            batch_first=True, dropout=dropout_rate if num_layers > 1 else 0)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.fc(out[:, -1, :])
        return out

# --- 2.3 Optimización con Optuna ---
# Preparar datos fuera de objective para evitar recálculos
X_train_data = df_train_scaled[features].values
y_train_data = df_train_scaled[TARGET].values

def objective(trial):
    params = {
        'n_layers': trial.suggest_int('n_layers', 1, 3),
        'hidden_size': trial.suggest_int('hidden_size', 32, 256, log=True),
        'dropout': trial.suggest_float('dropout', 0.1, 0.5),
        'lr': trial.suggest_float('lr', 1e-4, 1e-2, log=True),
        'batch_size': trial.suggest_categorical('batch_size', [16, 32, 64]),
        'sequence_length': trial.suggest_int('sequence_length', 8, 24)  # AJUSTE: Agregado como hiperparámetro
    }
    
    # Crear secuencias con el sequence_length del trial
    X_seq, y_seq = create_sequences(X_train_data, y_train_data, params['sequence_length'])
    
    # Verificar si hay suficientes datos
    if len(X_seq) < 10:
        return float('inf')
    
    split_index = int(len(X_seq) * 0.8)
    X_train, X_val = X_seq[:split_index], X_seq[split_index:]
    y_train, y_val = y_seq[:split_index], y_seq[split_index:]
    
    X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
    y_train_tensor = torch.tensor(y_train, dtype=torch.float32).view(-1, 1).to(device)
    X_val_tensor = torch.tensor(X_val, dtype=torch.float32).to(device)
    y_val_tensor = torch.tensor(y_val, dtype=torch.float32).view(-1, 1).to(device)
    
    train_loader = DataLoader(TensorDataset(X_train_tensor, y_train_tensor), 
                            batch_size=params['batch_size'], shuffle=True)
    val_loader = DataLoader(TensorDataset(X_val_tensor, y_val_tensor), 
                          batch_size=params['batch_size'], shuffle=False)
    
    model = LSTMModel(num_features, params['hidden_size'], params['n_layers'], 1, params['dropout']).to(device)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=params['lr'])
    
    epochs = 30
    for _ in range(epochs):
        model.train()
        for X_batch, y_batch in train_loader:
            optimizer.zero_grad()
            loss = criterion(model(X_batch), y_batch)
            loss.backward()
            optimizer.step()
    
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            val_loss += criterion(model(X_batch), y_batch).item()
    
    return val_loss / len(val_loader)

N_TRIALS = 40
print(f"\nIniciando optimización con Optuna ({N_TRIALS} trials)...")
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=N_TRIALS, timeout=600)
best_params = study.best_params
print(f"\nOptimización completada. Mejores hiperparámetros: {best_params}")

# ==============================================================================
# SECCIÓN 3: ENTRENAMIENTO FINAL Y GENERACIÓN DE PRONÓSTICOS
# ==============================================================================
from datetime import datetime

print("\n--- Iniciando Sección 3: Entrenamiento Final y Pronóstico ---")

# --- 3.1 Entrenamiento del Modelo Final ---
# Usar el mejor sequence_length encontrado
BEST_SEQUENCE_LENGTH = best_params['sequence_length']
print(f"Usando SEQUENCE_LENGTH óptimo: {BEST_SEQUENCE_LENGTH}")

X_seq, y_seq = create_sequences(X_train_data, y_train_data, BEST_SEQUENCE_LENGTH)

X_final_train_tensor = torch.tensor(X_seq, dtype=torch.float32).to(device)
y_final_train_tensor = torch.tensor(y_seq, dtype=torch.float32).view(-1, 1).to(device)
final_train_loader = DataLoader(TensorDataset(X_final_train_tensor, y_final_train_tensor), 
                              batch_size=best_params['batch_size'], shuffle=True)

final_model = LSTMModel(num_features, best_params['hidden_size'], best_params['n_layers'], 
                       1, best_params['dropout']).to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(final_model.parameters(), lr=best_params['lr'])

epochs = 60
print(f"Entrenando el modelo final por {epochs} épocas...")
for epoch in range(epochs):
    final_model.train()
    for X_batch, y_batch in final_train_loader:
        optimizer.zero_grad()
        loss = criterion(final_model(X_batch), y_batch)
        loss.backward()
        optimizer.step()
    if (epoch + 1) % 10 == 0:
        print(f'Epoch [{epoch+1}/{epochs}], Loss: {loss.item():.6f}')
print("Entrenamiento final completado.")

# --- 3.2 Generación de Pronósticos ---
print("\nGenerando pronósticos...")
final_model.eval()
last_sequence = torch.tensor(X_train_data[-BEST_SEQUENCE_LENGTH:], dtype=torch.float32).unsqueeze(0).to(device)
predictions = []

with torch.no_grad():
    for i in range(len(df_test_scaled)):
        predicted_target_scaled = final_model(last_sequence)
        predictions.append(predicted_target_scaled.item())
        future_exog_features = df_test_scaled[features].iloc[i].values
        new_sequence_np = np.append(last_sequence.cpu().numpy().squeeze(0)[1:], 
                                   future_exog_features.reshape(1, -1), axis=0)
        last_sequence = torch.tensor(new_sequence_np, dtype=torch.float32).unsqueeze(0).to(device)

predictions_descaled = scaler_target.inverse_transform(np.array(predictions).reshape(-1, 1))
# AJUSTE: Mantener dos decimales en lugar de redondear a enteros
final_predictions = np.round(predictions_descaled, 2).flatten()  # Redondear a 2 decimales
final_predictions[final_predictions < 0] = 0.00  # Asegurar que no haya valores negativos
print("Pronósticos generados.")

# --- 3.3 Creación del Archivo de Submission ---
submission_df = sample_submission.copy()
# Ensure predictions match submission length
if len(final_predictions) != len(submission_df):
    print(f"Warning: predictions ({len(final_predictions)}) and submission ({len(submission_df)}) length mismatch.")
    if len(final_predictions) > len(submission_df):
        final_predictions = final_predictions[:len(submission_df)]
    else:
        # Pad with zeros if predictions are shorter
        final_predictions = np.pad(final_predictions, (0, len(submission_df) - len(final_predictions)), 'constant')

# Assign after adjustment
submission_df[TARGET] = final_predictions
fecha_actual = datetime.now().strftime("%Y%m%d_%H%M%S")
SUBMISSION_FILE = f'output/submission_{fecha_actual}.csv'
submission_df.to_csv(SUBMISSION_FILE, index=False, float_format='%.2f')  # AJUSTE: Formato con 2 decimales
print(f"\nArchivo de submission '{SUBMISSION_FILE}' creado.")
print(submission_df.head())

# --- 3.4 Visualización de Resultados ---
plt.figure(figsize=(18, 7))
# Graficar datos históricos
df_train[TARGET].plot(label='Datos Históricos', alpha=0.75)
# Graficar predicciones
submission_index = pd.to_datetime(
    df_test_raw['anio'].astype(str) + df_test_raw['semana'].astype(str) + '-1',
    format='%Y%W-%w'
)
# Ensure index and predictions are the same length
if len(submission_index) != len(final_predictions):
    print(f"Warning: submission_index ({len(submission_index)}) and final_predictions ({len(final_predictions)}) length mismatch.")
    if len(submission_index) > len(final_predictions):
        submission_index = submission_index[-len(final_predictions):]
    else:
        final_predictions = final_predictions[-len(submission_index):]
predictions_series = pd.Series(final_predictions, index=submission_index)
predictions_series.plot(label='Pronóstico LSTM', style='r--')

plt.title('Pronóstico de Casos de Dengue vs. Datos Históricos')
plt.xlabel('Fecha (creada desde anio y semana)')
plt.ylabel('Número de Casos')
plt.legend(loc='upper left')
plt.savefig('output/final_forecast_vs_history.png')
plt.show()

print("\n--- Proceso Finalizado ---")
print(f"Mejor SEQUENCE_LENGTH encontrado: {BEST_SEQUENCE_LENGTH}")
print(f"Todos los mejores hiperparámetros: {best_params}")
# Out:
# Usando dispositivo: cuda
#
# --- Iniciando Sección 1: Carga y Análisis Exploratorio de Datos ---
# Archivos cargados exitosamente.
# Variable objetivo identificada como: 'dengue'
#
# Iniciando preprocesamiento de datos...
# Preprocesamiento completado.
# [I 2025-06-26 23:33:24,772] A new study created in memory with name: no-name-8fbe3a2a-aba8-4689-ad47-2cc33bc93361
# --- Iniciando Sección 2: Modelo LSTM y Optimización de Hiperparámetros ---
# Excluyendo la columna 'lluvia_min' de las características.
#
# Características finales para el modelo (2): ['lluvia_mean', 'temperatura_mean']
#
# Iniciando optimización con Optuna (40 trials)...
# [I 2025-06-26 23:33:29,540] Trial 0 finished with value: 0.01296828658087179 and parameters: {'n_layers': 1, 'hidden_size': 37, 'dropout': 0.14960461538272113, 'lr': 0.0007350991765591499, 'batch_size': 32, 'sequence_length': 20}. Best is trial 0 with value: 0.01296828658087179.
# [I 2025-06-26 23:33:31,552] Trial 1 finished with value: 0.013761217845603824 and parameters: {'n_layers': 1, 'hidden_size': 79, 'dropout': 0.2737811992385901, 'lr': 0.00020678220338362784, 'batch_size': 64, 'sequence_length': 21}. Best is trial 0 with value: 0.01296828658087179.
# [I 2025-06-26 23:33:35,443] Trial 2 finished with value: 0.013712345110252499 and parameters: {'n_layers': 1, 'hidden_size': 172, 'dropout': 0.1402343203793992, 'lr': 0.0015850756368140163, 'batch_size': 32, 'sequence_length': 9}. Best is trial 0 with value: 0.01296828658087179.
# [I 2025-06-26 23:33:37,754] Trial 3 finished with value: 0.013235616916790604 and parameters: {'n_layers': 2, 'hidden_size': 73, 'dropout': 0.17383391059067216, 'lr': 0.00041808260096426534, 'batch_size': 64, 'sequence_length': 16}. Best is trial 0 with value: 0.01296828658087179.
# [I 2025-06-26 23:33:41,769] Trial 4 finished with value: 0.013843100401572883 and parameters: {'n_layers': 1, 'hidden_size': 182, 'dropout': 0.47920038937119813, 'lr': 0.001090544521581874, 'batch_size': 32, 'sequence_length': 11}. Best is trial 0 with value: 0.01296828658087179.
# [I 2025-06-26 23:33:48,472] Trial 5 finished with value: 0.014210707967868075 and parameters: {'n_layers': 1, 'hidden_size': 56, 'dropout': 0.16730594446854552, 'lr': 0.009883325880370733, 'batch_size': 16, 'sequence_length': 14}. Best is trial 0 with value: 0.01296828658087179.
# [I 2025-06-26 23:33:52,490] Trial 6 finished with value: 0.014043817901983858 and parameters: {'n_layers': 2, 'hidden_size': 203, 'dropout': 0.45447362689840953, 'lr': 0.000140811722466675, 'batch_size': 64, 'sequence_length': 21}. Best is trial 0 with value: 0.01296828658087179.
# [I 2025-06-26 23:33:54,406] Trial 7 finished with value: 0.013913295511156321 and parameters: {'n_layers': 1, 'hidden_size': 74, 'dropout': 0.1165546241537995, 'lr': 0.00037835556880524187, 'batch_size': 64, 'sequence_length': 17}. Best is trial 0 with value: 0.01296828658087179.
# [I 2025-06-26 23:34:03,531] Trial 8 finished with value: 0.01312294710369315 and parameters: {'n_layers': 3, 'hidden_size': 74, 'dropout': 0.32807942718816574, 'lr': 0.00019767624870220015, 'batch_size': 16, 'sequence_length': 20}. Best is trial 0 with value: 0.01296828658087179.
# [I 2025-06-26 23:34:12,000] Trial 9 finished with value: 0.013887361710658297 and parameters: {'n_layers': 2, 'hidden_size': 47, 'dropout': 0.42355570255888053, 'lr': 0.007827621821043624, 'batch_size': 16, 'sequence_length': 15}. Best is trial 0 with value: 0.01296828658087179.
# [I 2025-06-26 23:34:17,220] Trial 10 finished with value: 0.013044567930046469 and parameters: {'n_layers': 3, 'hidden_size': 32, 'dropout': 0.26380351744987485, 'lr': 0.0023881969838020958, 'batch_size': 32, 'sequence_length': 24}. Best is trial 0 with value: 0.01296828658087179.
# [I 2025-06-26 23:34:21,541] Trial 11 finished with value: 0.013457479362841696 and parameters: {'n_layers': 3, 'hidden_size': 33, 'dropout': 0.2584194172971823, 'lr': 0.0026143650739905606, 'batch_size': 32, 'sequence_length': 24}. Best is trial 0 with value: 0.01296828658087179.
# [I 2025-06-26 23:34:26,397] Trial 12 finished with value: 0.013405795150902122 and parameters: {'n_layers': 3, 'hidden_size': 36, 'dropout': 0.23517907721038495, 'lr': 0.0034429719139009484, 'batch_size': 32, 'sequence_length': 24}. Best is trial 0 with value: 0.01296828658087179.
# [I 2025-06-26 23:34:31,050] Trial 13 finished with value: 0.013056580326519907 and parameters: {'n_layers': 3, 'hidden_size': 46, 'dropout': 0.3421473673584419, 'lr': 0.0005447048190549165, 'batch_size': 32, 'sequence_length': 19}. Best is trial 0 with value: 0.01296828658087179.
# [I 2025-06-26 23:34:37,088] Trial 14 finished with value: 0.012916715675964951 and parameters: {'n_layers': 2, 'hidden_size': 129, 'dropout': 0.2074636553074387, 'lr': 0.0033247055239838527, 'batch_size': 32, 'sequence_length': 23}. Best is trial 14 with value: 0.012916715675964951.
# [I 2025-06-26 23:34:40,772] Trial 15 finished with value: 0.013762814900837838 and parameters: {'n_layers': 2, 'hidden_size': 125, 'dropout': 0.20227547626796316, 'lr': 0.004925384234132151, 'batch_size': 32, 'sequence_length': 18}. Best is trial 14 with value: 0.012916715675964951.
# [I 2025-06-26 23:34:44,483] Trial 16 finished with value: 0.01321343801682815 and parameters: {'n_layers': 2, 'hidden_size': 108, 'dropout': 0.21028903641594218, 'lr': 0.0007836835691144068, 'batch_size': 32, 'sequence_length': 22}. Best is trial 14 with value: 0.012916715675964951.
# [I 2025-06-26 23:34:50,330] Trial 17 finished with value: 0.013075544580351562 and parameters: {'n_layers': 2, 'hidden_size': 141, 'dropout': 0.10076019915899176, 'lr': 0.0014887463873076894, 'batch_size': 32, 'sequence_length': 22}. Best is trial 14 with value: 0.012916715675964951.
# [I 2025-06-26 23:34:54,980] Trial 18 finished with value: 0.01325715909479186 and parameters: {'n_layers': 1, 'hidden_size': 236, 'dropout': 0.16273971410100233, 'lr': 0.004484920610974358, 'batch_size': 32, 'sequence_length': 18}. Best is trial 14 with value: 0.012916715675964951.
# [I 2025-06-26 23:35:01,168] Trial 19 finished with value: 0.013731415080837906 and parameters: {'n_layers': 1, 'hidden_size': 96, 'dropout': 0.3760436572673695, 'lr': 0.0008135818023267193, 'batch_size': 16, 'sequence_length': 13}. Best is trial 14 with value: 0.012916715675964951.
# [I 2025-06-26 23:35:07,094] Trial 20 finished with value: 0.013278623262885958 and parameters: {'n_layers': 2, 'hidden_size': 147, 'dropout': 0.20976909457118031, 'lr': 0.001749295792379636, 'batch_size': 32, 'sequence_length': 22}. Best is trial 14 with value: 0.012916715675964951.
# [I 2025-06-26 23:35:11,637] Trial 21 finished with value: 0.014044164877850563 and parameters: {'n_layers': 3, 'hidden_size': 41, 'dropout': 0.2920368253817137, 'lr': 0.002282873190348346, 'batch_size': 32, 'sequence_length': 24}. Best is trial 14 with value: 0.012916715675964951.
# [I 2025-06-26 23:35:16,078] Trial 22 finished with value: 0.013965332228690387 and parameters: {'n_layers': 3, 'hidden_size': 58, 'dropout': 0.2531318490482262, 'lr': 0.006035708197489981, 'batch_size': 32, 'sequence_length': 23}. Best is trial 14 with value: 0.012916715675964951.
# [I 2025-06-26 23:35:20,187] Trial 23 finished with value: 0.013050802249927074 and parameters: {'n_layers': 2, 'hidden_size': 32, 'dropout': 0.2292492364956628, 'lr': 0.003071595127816461, 'batch_size': 32, 'sequence_length': 20}. Best is trial 14 with value: 0.012916715675964951.
# [I 2025-06-26 23:35:24,589] Trial 24 finished with value: 0.013115635071881116 and parameters: {'n_layers': 3, 'hidden_size': 58, 'dropout': 0.30371076238236744, 'lr': 0.0009963272841633547, 'batch_size': 32, 'sequence_length': 23}. Best is trial 14 with value: 0.012916715675964951.
# [I 2025-06-26 23:35:28,581] Trial 25 finished with value: 0.013530952006112784 and parameters: {'n_layers': 2, 'hidden_size': 39, 'dropout': 0.1406706739003445, 'lr': 0.0018361245714492533, 'batch_size': 32, 'sequence_length': 20}. Best is trial 14 with value: 0.012916715675964951.
# [I 2025-06-26 23:35:32,118] Trial 26 finished with value: 0.013006222632247955 and parameters: {'n_layers': 1, 'hidden_size': 50, 'dropout': 0.18694689855044855, 'lr': 0.003562262721978939, 'batch_size': 32, 'sequence_length': 23}. Best is trial 14 with value: 0.012916715675964951.
# [I 2025-06-26 23:35:35,639] Trial 27 finished with value: 0.013304700225125999 and parameters: {'n_layers': 1, 'hidden_size': 49, 'dropout': 0.1845383297453324, 'lr': 0.00047954291817948113, 'batch_size': 32, 'sequence_length': 21}. Best is trial 14 with value: 0.012916715675964951.
# [I 2025-06-26 23:35:41,739] Trial 28 finished with value: 0.0139421095198486 and parameters: {'n_layers': 1, 'hidden_size': 103, 'dropout': 0.130757927409683, 'lr': 0.004028263336812209, 'batch_size': 16, 'sequence_length': 19}. Best is trial 14 with value: 0.012916715675964951.
# [I 2025-06-26 23:35:43,712] Trial 29 finished with value: 0.013984809070825577 and parameters: {'n_layers': 1, 'hidden_size': 86, 'dropout': 0.15020636931976789, 'lr': 0.0002973309956811109, 'batch_size': 64, 'sequence_length': 23}. Best is trial 14 with value: 0.012916715675964951.
# [I 2025-06-26 23:35:45,568] Trial 30 finished with value: 0.013508119666948915 and parameters: {'n_layers': 1, 'hidden_size': 67, 'dropout': 0.1971934865518748, 'lr': 0.0061875680255832856, 'batch_size': 64, 'sequence_length': 22}. Best is trial 14 with value: 0.012916715675964951.
# [I 2025-06-26 23:35:49,276] Trial 31 finished with value: 0.013092560472432523 and parameters: {'n_layers': 1, 'hidden_size': 41, 'dropout': 0.2860071409513406, 'lr': 0.002571492701551472, 'batch_size': 32, 'sequence_length': 24}. Best is trial 14 with value: 0.012916715675964951.
# [I 2025-06-26 23:35:53,547] Trial 32 finished with value: 0.01358582794200629 and parameters: {'n_layers': 2, 'hidden_size': 36, 'dropout': 0.2477924619888624, 'lr': 0.0013348839842401504, 'batch_size': 32, 'sequence_length': 8}. Best is trial 14 with value: 0.012916715675964951.
# [I 2025-06-26 23:35:57,871] Trial 33 finished with value: 0.013121873512864113 and parameters: {'n_layers': 1, 'hidden_size': 32, 'dropout': 0.22244792340694333, 'lr': 0.002258838372617266, 'batch_size': 32, 'sequence_length': 23}. Best is trial 14 with value: 0.012916715675964951.
# [I 2025-06-26 23:36:01,923] Trial 34 finished with value: 0.013254768366459757 and parameters: {'n_layers': 1, 'hidden_size': 50, 'dropout': 0.1771880726697313, 'lr': 0.0007022467375391169, 'batch_size': 32, 'sequence_length': 21}. Best is trial 14 with value: 0.012916715675964951.
# [I 2025-06-26 23:36:05,134] Trial 35 finished with value: 0.013156946352683007 and parameters: {'n_layers': 1, 'hidden_size': 123, 'dropout': 0.27110340803998706, 'lr': 0.0012456164312469149, 'batch_size': 32, 'sequence_length': 23}. Best is trial 14 with value: 0.012916715675964951.
# [I 2025-06-26 23:36:09,609] Trial 36 finished with value: 0.013436832290608436 and parameters: {'n_layers': 3, 'hidden_size': 42, 'dropout': 0.1870031983970296, 'lr': 0.0032662045688892716, 'batch_size': 32, 'sequence_length': 12}. Best is trial 14 with value: 0.012916715675964951.
# [I 2025-06-26 23:36:11,637] Trial 37 finished with value: 0.013301816815510393 and parameters: {'n_layers': 2, 'hidden_size': 66, 'dropout': 0.1596738868031775, 'lr': 0.005609985633700403, 'batch_size': 64, 'sequence_length': 21}. Best is trial 14 with value: 0.012916715675964951.
# [I 2025-06-26 23:36:15,633] Trial 38 finished with value: 0.014080348960123956 and parameters: {'n_layers': 1, 'hidden_size': 172, 'dropout': 0.11998634025885561, 'lr': 0.00010192868690314948, 'batch_size': 32, 'sequence_length': 16}. Best is trial 14 with value: 0.012916715675964951.
# [I 2025-06-26 23:36:23,542] Trial 39 finished with value: 0.013603435311233624 and parameters: {'n_layers': 2, 'hidden_size': 36, 'dropout': 0.30999988951756974, 'lr': 0.0018479829781602479, 'batch_size': 16, 'sequence_length': 10}. Best is trial 14 with value: 0.012916715675964951.
# Optimización completada. Mejores hiperparámetros: {'n_layers': 2, 'hidden_size': 129, 'dropout': 0.2074636553074387, 'lr': 0.0033247055239838527, 'batch_size': 32, 'sequence_length': 23}
#
# --- Iniciando Sección 3: Entrenamiento Final y Pronóstico ---
# Usando SEQUENCE_LENGTH óptimo: 23
# Entrenando el modelo final por 60 épocas...
# Epoch [10/60], Loss: 0.014174
# Epoch [20/60], Loss: 0.017603
# Epoch [30/60], Loss: 0.009820
# Epoch [40/60], Loss: 0.008132
# Epoch [50/60], Loss: 0.064586
# Epoch [60/60], Loss: 0.007953
# Entrenamiento final completado.
#
# Generando pronósticos...
# Pronósticos generados.
# Warning: predictions (530) and submission (520) length mismatch.
#
# Archivo de submission 'output/submission_20250626_233638.csv' creado.
#           id  dengue
# 0  4_2022_01    2.82
# 1  5_2022_01    2.82
# 2  3_2022_01    2.77
# 3  8_2022_01    2.47
# 4  9_2022_01    2.47
# Warning: submission_index (530) and final_predictions (520) length mismatch.
# --- Proceso Finalizado ---
# Mejor SEQUENCE_LENGTH encontrado: 23
# Todos los mejores hiperparámetros: {'n_layers': 2, 'hidden_size': 129, 'dropout': 0.2074636553074387, 'lr': 0.0033247055239838527, 'batch_size': 32, 'sequence_length': 23}
